# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %%
prototxt = "model/colorization_deploy_v2.prototxt"
model = "model/colorization_release_v2.caffemodel"
points = "model/pts_in_hull.npy"

# %%
net = cv2.dnn.readNetFromCaffe(prototxt, model)
pts = np.load(points)

# %%
class8 = net.getLayerId("class8_ab")
conv8 = net.getLayerId("conv8_313_rh")
pts = pts.transpose().reshape(2, 313, 1, 1)

# %%
net.getLayer(class8).blobs = [pts.astype("float32")]
net.getLayer(conv8).blobs = [np.full([1, 313], 2.606, dtype="float32")]

# %%
testpath = 'data/test'
import cv2
files = os.listdir(testpath)
for idx, file in enumerate(files):
    
    image = cv2.imread(testpath+'/'+file)
    save = image
    window_name = 'image'
  
    print(testpath+file)
    cv2.imshow(window_name, image)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
    
    scaled = image.astype("float32") / 255.0
    lab = cv2.cvtColor(scaled, cv2.COLOR_RGB2LAB)
    resized = cv2.resize(lab, (224, 224))
    L = cv2.split(resized)[0]
    L -= 50
    
    net.setInput(cv2.dnn.blobFromImage(L))
    ab = net.forward()[0, :, :, :].transpose((1, 2, 0))
    ab = cv2.resize(ab, (image.shape[1], image.shape[0]))
    
    L = cv2.split(lab)[0]
    colorized = np.concatenate((L[:, :, np.newaxis], ab), axis=2)
    
    colorized = cv2.cvtColor(colorized, cv2.COLOR_LAB2RGB)
    colorized = np.clip(colorized, 0, 1)
    colorized = (255 * colorized).astype("uint8")
    
    fig = plt.figure(figsize=(30,20), dpi=100)
    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.imshow(save)
    ax2.imshow(colorized)
    
    cv2.imwrite('data/output/'+str(idx)+".jpg", colorized)
# Out:
# data/test2683437.main_image.jpg
# data/test5512939989_6f8a225663_b.jpg
# data/test81OWc-HXpQL._AC_SL1500_.jpg
# data/testA0013387_1024x1024.jpg
# data/testa91b0343b5af12b061e66d1d1c401d90.jpg
# data/testblack-and-white-2654079_1280.jpg
# data/testblack-and-white-barn-michelle-kelnhofer.jpg
# data/testblack-white-picture-beautiful-wooden-260nw-1989788087.jpg
# data/testdia mirza.jpg
# data/testdownload.jpg
# data/testf3418c37d59089559ae5139cb3f3aabc.jpg
# <ipython-input-12-0a5da993c43b>:32: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=(30,20), dpi=100)
# data/testfour-chairs-at-sunset-florida_u-l-pz5as00.jpg
# data/testimages (1).jpg
# data/testimages.jpg
# data/testlpIPtn.jpg
# data/testparis-architecture-1540212.jpg
# data/testpexels-goashape-39110.jpg
# data/testphotoshop-black-and-white-desaturate.jpg
# data/testpngtree-modern-city-black-and-white-buildings-png-image_5647874.jpg
# data/testswiming-tree-1389730.jpg
